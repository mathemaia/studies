# %%
import pandas as pd

df = pd.read_csv('vitimas.csv', sep=';')
df
# Out:
#                    data              hora  idade       sexo sit_vitima  \
# 0      01/01/2017 00:00  19:15:00.0000000     47  MASCULINO   PEDESTRE
# 1      01/01/2017 00:00  19:10:00.0000000     35  MASCULINO   CONDUTOR
# 2      01/01/2017 00:00  22:00:00.0000000     46  MASCULINO   CONDUTOR
# 3      01/01/2017 00:00  10:00:00.0000000     30   FEMININO   CONDUTOR
# 4      02/01/2017 00:00  20:33:00.0000000     41  MASCULINO   PEDESTRE
# ...                 ...               ...    ...        ...        ...
# 28050  29/09/2022 00:00  21:35:00.0000000     25  MASCULINO   CONDUTOR
# 28051  29/09/2022 00:00  22:04:00.0000000     28  MASCULINO   CONDUTOR
# 28052  29/09/2022 00:00  17:00:00.0000000     20  MASCULINO   CONDUTOR
# 28053  29/09/2022 00:00  11:45:00.0000000     21  MASCULINO   CONDUTOR
# 28054  29/09/2022 00:00  10:35:00.0000000     24  MASCULINO   CONDUTOR
#
#                                 log1       tipo_acid  auto  taxi  onibus_urb  \
# ...

# %%
colunas = df.columns.to_list()
colunas
# Out:
# ['data',
#  'hora',
#  'idade',
#  'sexo',
#  'sit_vitima',
#  'log1',
#  'tipo_acid',
#  'auto',
#  'taxi',
#  'onibus_urb',
#  'onibus_met',
#  'onibus_int',
#  'caminhao',
#  'moto',
#  'carroca',
#  'bicicleta',
#  'outro',
#  'lotacao',
#  'dia_sem',
#  'periododia',
#  'fx_et',
#  'tipo_veic']

# %%
df['moto']
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 28050    1
# 28051    1
# 28052    1
# 28053    1
# 28054    1
# Name: moto, Length: 28055, dtype: int64
