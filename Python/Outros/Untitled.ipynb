# %%
import pandas as pd

tabela = pd.read_csv('pokemon.csv')
display(tabela)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
tabela
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
print('somatório: ', tabela['HP'].sum())
print('quantidade: ', tabela['HP'].count())
print(tabela['HP'].mean())
# Out:
# somatório:  55407
# quantidade:  800
# 69.25875

# %%
import random

series = []
for i in range(100):
    series.append(random.randint(0, 3))

s = pd.Series(series)
display(s, s.sum(), s.count(), (s.sum() / s.count()))
# Out:
# 0     0
# 1     2
# 2     0
# 3     3
# 4     1
#      ..
# 95    2
# 96    3
# 97    3
# 98    1
# 99    3
# Length: 100, dtype: int64
# 151
# 100
# 1.51

# %% [markdown]
# # Gerador de datas ordenadas

# %%
aniversarios = pd.date_range('20220101', periods=78)
aniversarios
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10', '2022-01-11', '2022-01-12',
#                '2022-01-13', '2022-01-14', '2022-01-15', '2022-01-16',
#                '2022-01-17', '2022-01-18', '2022-01-19', '2022-01-20',
#                '2022-01-21', '2022-01-22', '2022-01-23', '2022-01-24',
#                '2022-01-25', '2022-01-26', '2022-01-27', '2022-01-28',
#                '2022-01-29', '2022-01-30', '2022-01-31', '2022-02-01',
#                '2022-02-02', '2022-02-03', '2022-02-04', '2022-02-05',
#                '2022-02-06', '2022-02-07', '2022-02-08', '2022-02-09',
#                '2022-02-10', '2022-02-11', '2022-02-12', '2022-02-13',
#                '2022-02-14', '2022-02-15', '2022-02-16', '2022-02-17',
#                '2022-02-18', '2022-02-19', '2022-02-20', '2022-02-21',
# ...

# %% [markdown]
# # Criando datasets

# %%
data_frame = pd.DataFrame(0, index=aniversarios, columns=list('ABC'))
display(data_frame, data_frame.count())
# Out:
#             A  B  C
# 2022-01-01  0  0  0
# 2022-01-02  0  0  0
# 2022-01-03  0  0  0
# 2022-01-04  0  0  0
# 2022-01-05  0  0  0
# ...        .. .. ..
# 2022-03-15  0  0  0
# 2022-03-16  0  0  0
# 2022-03-17  0  0  0
# 2022-03-18  0  0  0
# 2022-03-19  0  0  0
#
# [78 rows x 3 columns]
# A    78
# B    78
# C    78
# dtype: int64
